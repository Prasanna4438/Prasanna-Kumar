# %%
import numpy as np, pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns, sklearn

# %%
data = sns.load_dataset('titanic')

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df = data.copy()

# %%
df.loc[df['embark_town'].isnull()] # missing values in emabrk_town
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
sns.countplot(data = df, x = 'pclass', hue = 'embark_town')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
column_name = 'embark_town'
imputation_value = 'Southampton' # filling the na na vakue with southhampton

df[column_name] = df[column_name].fillna(imputation_value)

# %%
df.loc[df['embarked'].isnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck  embark_town alive  alone
# 61   woman       False    B  Southampton   yes   True
# 829  woman       False    B  Southampton   yes   True

# %%
column_name = 'embarked'
imputation_value = 's' # filling the na na vakue with southhampton

df[column_name] = df[column_name].fillna(imputation_value)

# %%
df['age'].fillna(df['age'].mean(), inplace = True)

# %%
df.drop('deck', axis = 1, inplace =True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
sns.histplot(data = data, x = 'age', kde = True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data = df, x = 'age', kde = True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df1 =df.copy()

# %%
df1['age'].fillna(df1['age'].median(), inplace = True)

# %%
sns.histplot(data = df1, x = 'age', kde = True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df2=data.copy()
df2['age']=data['age'].ffill() ## forward filling 
sns.histplot(x='age',data=df2,kde=True)## it gives correct,but it crossing the count
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df3=data.copy()
df3['age']=data['age'].bfill() ## backward filling 
sns.histplot(x='age',data=df3,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df4=data.copy()
df4['age']=data['age'].interpolate() 
sns.histplot(data=df4,x='age',kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(data=data, x='age', kde=True, ax=ax, label='Data') #the orginal data
sns.histplot(data=df, x='age', kde=True, ax=ax, label='df') # data imputed with mean
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(data=data, x='age', kde=True, ax=ax, label='Data') #the orginal data
sns.histplot(data=df1, x='age', kde=True, ax=ax, label='df1') # data imputed with median
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(data=data, x='age', kde=True, ax=ax, label='Data') #the orginal data
sns.histplot(data=df2, x='age', kde=True, ax=ax, label='df2') # data imputed with forward filling
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(data=data, x='age', kde=True, ax=ax, label='Data') #the orginal data
sns.histplot(data=df3, x='age', kde=True, ax=ax, label='df3') # data imputed with backward filling
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(data=data, x='age', kde=True, ax=ax, label='Data') #the orginal data
sns.histplot(data=df4, x='age', kde=True, ax=ax, label='df4') # data imputed with interpolation filling
ax.legend()
plt.show()

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
sns.distplot(df.groupby(['embarked'])['age'].transform(lambda x : x.fillna(x.median())), kde = True, hist = True, bins = 20)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df['age'].ffill().bfill(), kde = True, hist = True, bins = 20)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df['age'], kde = True, hist = True, bins = 20)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
def luFence(x):

    iqr = x.quantile(0.75) - x.quantile(0.25)
    lowerFence, upperFence = max(min(x), x.quantile(0.25)-1.5*iqr), min(max(x), x.quantile(0.75)+1.5*iqr)
    return lowerFence, upperFence

# %%
luFence(df['fare'])
# Out:
# (0.0, 65.6344)

# %%
sns.boxplot(df['fare'])
# Out:
# <Axes: >

# %%
df[df['fare']<=65.6344].groupby(['embark_town', 'pclass'])['fare'].median()
# Out:
# embark_town  pclass
# Cherbourg    1         34.6542
#              2         24.0000
#              3          7.8958
# Queenstown   2         12.3500
#              3          7.7500
# Southampton  1         30.5000
#              2         13.5000
#              3          8.0500
# Name: fare, dtype: float64

# %%
df.groupby('pclass')['fare'].median()
# Out:
# pclass
# 1    60.2875
# 2    14.2500
# 3     8.0500
# Name: fare, dtype: float64

# %%
df[(df['fare']>=60.2875) & (df['pclass']==1)]['fare'].describe()
# Out:
# count    108.000000
# mean     132.179358
# std       86.499434
# min       61.175000
# 25%       79.200000
# 50%       93.500000
# 75%      151.550000
# max      512.329200
# Name: fare, dtype: float64

# %%
Q1 = df['fare'].quantile(0.25)
Q3 = df['fare'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['fare'] < lower_bound) | (df['fare'] > upper_bound)]

print("Outliers:")
print(outliers)

total_outliers = len(outliers)
print(f"Total Outliers: {total_outliers}")
# Out:
# Outliers:
#      survived  pclass     sex        age  sibsp  parch      fare embarked  \
# 1           1       1  female  38.000000      1      0   71.2833        C
# 27          0       1    male  19.000000      3      2  263.0000        S
# 31          1       1  female  29.699118      1      0  146.5208        C
# 34          0       1    male  28.000000      1      0   82.1708        C
# 52          1       1  female  49.000000      1      0   76.7292        C
# ..        ...     ...     ...        ...    ...    ...       ...      ...
# 846         0       3    male  29.699118      8      2   69.5500        S
# 849         1       1  female  29.699118      1      0   89.1042        C
# 856         1       1  female  45.000000      1      1  164.8667        S
# 863         0       3  female  29.699118      8      2   69.5500        S
# 879         1       1  female  56.000000      0      1   83.1583        C
#
#      class    who  adult_male  embark_town alive  alone
# ...

# %%
outliers_count_by_pclass = outliers.groupby('pclass').size().reset_index(name='outliers_count')
print(outliers_count_by_pclass)
# Out:
#    pclass  outliers_count
# 0       1             104
# 1       2               5
# 2       3               7

# %%
grouped_data = df.groupby('pclass')

# %%
pclass_1 = grouped_data.get_group(1)

# %%
pclass_1['fare']
# Out:
# 1      71.2833
# 3      53.1000
# 6      51.8625
# 11     26.5500
# 23     35.5000
#         ...
# 871    52.5542
# 872     5.0000
# 879    83.1583
# 887    30.0000
# 889    30.0000
# Name: fare, Length: 216, dtype: float64

# %%
x = np.percentile(pclass_1['fare'],[25,50,75])
iqr = x[2]-x[0]

# %%
lowerFence, upperFence = max(min(pclass_1['fare']), pclass_1['fare'].quantile(0.25)-1.5*iqr), min(max(pclass_1['fare']), pclass_1['fare'].quantile(0.75)+1.5*iqr)

# %%
print(lowerFence)
print(upperFence)
# Out:
# 0.0
# 187.364075

# %%
pclass_1.boxplot('fare')
# Out:
# <Axes: >

# %%
pclass_1[pclass_1['fare']<lowerFence]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, embark_town, alive, alone]
# Index: []

# %%
pclass_1[pclass_1['fare']>upperFence]['fare']=187.364075

# %%
pclass_1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 11          1       1  female  58.0      0      0  26.5500        S  First
# 23          1       1    male  28.0      0      0  35.5000        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
pclass_1['fare'] = np.where(pclass_1['fare'] > upperFence, 187.364075, pclass_1['fare'])

# %%
pclass_1.boxplot('fare')
# Out:
# <Axes: >

# %%
pclass_2 = grouped_data.get_group(2)

# %%
pclass_2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 9           1       2  female  14.000000      1      0  30.0708        C
# 15          1       2  female  55.000000      0      0  16.0000        S
# 17          1       2    male  29.699118      0      0  13.0000        S
# 20          0       2    male  35.000000      0      0  26.0000        S
# 21          1       2    male  34.000000      0      0  13.0000        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 866         1       2  female  27.000000      1      0  13.8583        C
# 874         1       2  female  28.000000      1      0  24.0000        C
# 880         1       2  female  25.000000      0      1  26.0000        S
# 883         0       2    male  28.000000      0      0  10.5000        S
# 886         0       2    male  27.000000      0      0  13.0000        S
#
#       class    who  adult_male  embark_town alive  alone
# ...

# %%
x = np.percentile(pclass_2['fare'],[25,50,75])
iqr = x[2]-x[0]

# %%
lowerFence, upperFence = max(min(pclass_2['fare']), pclass_2['fare'].quantile(0.25)-1.5*iqr), min(max(pclass_2['fare']), pclass_2['fare'].quantile(0.75)+1.5*iqr)

# %%
print(lowerFence)
print(upperFence)
# Out:
# 0.0
# 45.5

# %%
pclass_2.boxplot('fare')
# Out:
# <Axes: >

# %%
pclass_2[pclass_2['fare']<lowerFence]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, embark_town, alive, alone]
# Index: []

# %%
pclass_2[pclass_2['fare']>upperFence]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked   class  \
# 72          0       2    male  21.0      0      0  73.5        S  Second
# 120         0       2    male  21.0      2      0  73.5        S  Second
# 385         0       2    male  18.0      0      0  73.5        S  Second
# 615         1       2  female  24.0      1      2  65.0        S  Second
# 655         0       2    male  24.0      2      0  73.5        S  Second
# 665         0       2    male  32.0      2      0  73.5        S  Second
# 754         1       2  female  48.0      1      2  65.0        S  Second
#
#        who  adult_male  embark_town alive  alone
# 72     man        True  Southampton    no   True
# 120    man        True  Southampton    no  False
# 385    man        True  Southampton    no   True
# 615  woman       False  Southampton   yes  False
# 655    man        True  Southampton    no  False
# 665    man        True  Southampton    no  False
# ...

# %%
pclass_2['fare'] = np.where(pclass_2['fare'] > upperFence, 45.5, pclass_2['fare'])

# %%
pclass_2.boxplot('fare')
# Out:
# <Axes: >

# %%
pclass_3 = grouped_data.get_group(3)

# %%
pclass_3
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 2           1       3  female  26.000000      0      0   7.9250        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# 5           0       3    male  29.699118      0      0   8.4583        Q
# 7           0       3    male   2.000000      3      1  21.0750        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 882         0       3  female  22.000000      0      0  10.5167        S
# 884         0       3    male  25.000000      0      0   7.0500        S
# 885         0       3  female  39.000000      0      5  29.1250        Q
# 888         0       3  female  29.699118      1      2  23.4500        S
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#      class    who  adult_male  embark_town alive  alone
# ...

# %%
x = np.percentile(pclass_3['fare'],[25,50,75])
iqr = x[2]-x[0]

# %%
lowerFence, upperFence = max(min(pclass_3['fare']), pclass_3['fare'].quantile(0.25)-1.5*iqr), min(max(pclass_3['fare']), pclass_3['fare'].quantile(0.75)+1.5*iqr)

# %%
print(lowerFence)
print(upperFence)
# Out:
# 0.0
# 27.125

# %%
pclass_3.boxplot('fare')
# Out:
# <Axes: >

# %%
pclass_2[pclass_2['fare']<lowerFence]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, embark_town, alive, alone]
# Index: []

# %%
pclass_3[pclass_3['fare']>upperFence]
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 13          0       3    male  39.000000      1      5  31.2750        S
# 16          0       3    male   2.000000      4      1  29.1250        Q
# 25          1       3  female  38.000000      1      5  31.3875        S
# 50          0       3    male   7.000000      4      1  39.6875        S
# 59          0       3    male  11.000000      5      2  46.9000        S
# 63          0       3    male   4.000000      3      2  27.9000        S
# 71          0       3  female  16.000000      5      2  46.9000        S
# 74          1       3    male  32.000000      0      0  56.4958        S
# 86          0       3    male  16.000000      1      3  34.3750        S
# 119         0       3  female   2.000000      4      2  31.2750        S
# 147         0       3  female   9.000000      2      2  34.3750        S
# 159         0       3    male  29.699118      8      2  69.5500        S
# ...

# %%
pclass_3['fare'] = np.where(pclass_3['fare'] > upperFence, 27.125, pclass_3['fare'])

# %%
pclass_3.boxplot('fare')
# Out:
# <Axes: >

# %%
df4 = pd.concat([pclass_1, pclass_2, pclass_3])

# %%
df4
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 1           1       1  female  38.000000      1      0  71.2833        C
# 3           1       1  female  35.000000      1      0  53.1000        S
# 6           0       1    male  54.000000      0      0  51.8625        S
# 11          1       1  female  58.000000      0      0  26.5500        S
# 23          1       1    male  28.000000      0      0  35.5000        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 882         0       3  female  22.000000      0      0  10.5167        S
# 884         0       3    male  25.000000      0      0   7.0500        S
# 885         0       3  female  39.000000      0      5  27.1250        Q
# 888         0       3  female  29.699118      1      2  23.4500        S
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#      class    who  adult_male  embark_town alive  alone
# ...

# %%
df4.boxplot('fare')
# Out:
# <Axes: >

# %%
sns.scatterplot(x='age', y='fare', data=df)
plt.title('Scatter Plot: Age vs. Fare')
plt.show()

# %%
sns.countplot(x='pclass', hue='survived', data=df)
plt.title('Bar Plot: Pclass vs. Survival')
plt.show()

# %%
sns.boxplot(x='pclass', y='age', data=df)
plt.title('Box Plot: Pclass vs. Age')
plt.show()

# %%
sns.countplot(x='embarked', hue='survived', data=df)
plt.title('Count Plot: Embarked vs. Survival')
plt.show()

# %%
sns.violinplot(x='pclass', y='age', data=df, inner='quartile', palette='pastel')
plt.title('Violin Plot: Pclass vs. Age')
plt.show()

# %%
df['pclass_mirror'] = np.where(df['pclass'] == 1, 3, np.where(df['pclass'] == 3, 1, df['pclass']))

# Set up the matplotlib figure
plt.figure(figsize=(10, 6))

# Create the mirrored kernel density plots
sns.kdeplot(df[df['pclass'] == 1]['age'], label='1st Class', shade=True, color='blue')
sns.kdeplot(df[df['pclass'] == 2]['age'], label='2nd Class', shade=True, color='orange')
sns.kdeplot(df[df['pclass'] == 3]['age'], label='3rd Class', shade=True, color='green')

sns.kdeplot(df[df['pclass'] == 1]['age'], label='', shade=True, color='blue')
sns.kdeplot(df[df['pclass'] == 2]['age'], label='', shade=True, color='orange')
sns.kdeplot(df[df['pclass'] == 3]['age'], label='', shade=True, color='green')

# Remove the mirrored passenger class column
df.drop('pclass_mirror', axis=1, inplace=True)

# Set labels and title
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Butterfly Plot: Pclass vs. Age')
plt.legend(title='Passenger Class')

# Show the plot
plt.show()

# %%
sns.pairplot(df, hue='survived', diag_kind='kde')
plt.suptitle('Pair Plot of Numerical Variables')
plt.show()

# %%
g = sns.FacetGrid(df, col='pclass', height=4, col_wrap=3)
g.map(plt.hist, 'age', bins=20)
plt.suptitle('FacetGrid: Age Distribution by Pclass')
plt.show()
